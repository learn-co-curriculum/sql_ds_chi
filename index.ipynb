# %% [markdown]
# ![sql](img/sql-logo.jpg)
#
# # A beginner's guide to databases, SQL, & using them with `pandas`

# %% [markdown]
# **Scenario:** You are a data analyst for the Homeland Security, trying to create reports on the active airports world wide. The data you need to access is in a SQL database. YOu need to be able to query for the data in a database!

# %% [markdown]
# Activation: Here are a bunch of tools and concepts. Let's make three bins for data analyst, data scientist, and data engineer on the board.  Put the words in a bin. They can go in multiple bins.

# %% [markdown]
# words = [python, sql, predictions, eda, machine learning, ai, pyspark, hadoop, tableau, relational database, jupyter notebook, aws, nosql, pipeline, recommendation system, data lake]

# %% [markdown]
# ## Learning goals:
# - Goal 1: Summarize the use case for sql in the data science skill set
# - Goal 2: Define key sql terminology
# - Goal 3: Use basic SQL commands:
#     - Construct SQL queries
#     - Use JOIN to merge tables along logical columns
#     - Grouping Data with SQL
# - Goal 4: Convert SQL to pandas

# %% [markdown]
# ## Goal 1: Summarize
#
# To date the data we've seen has looked like [this.](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Intakes/wter-evkm)
#
# That is how we need data to look to run analysis and build models.<br>
# But it doesn't _live_ there in it's native state.

# %% [markdown]
# [Netflix has a great article](https://medium.com/netflix-techblog/notebook-innovation-591ee3221233) describing three different data roles at their company, their different needs, and their toolsets.
#
# ![netflix](img/netflix-data-roles.jpeg)
#
# Examining that graphic, SQL shows up as one of the tools of the _Data Engineer_

# %% [markdown]
# Data Engineers provide the essential data architecture services that make data science possible.
#
# ![hierarchy](img/ai-hierachy.png)
#
# [Source: Monica Rogati’s fantastic Medium post “The AI Hierarchy of Needs”
# ](https://hackernoon.com/the-ai-hierarchy-of-needs-18f111fcc007)

# %% [markdown]
# ## What does it mean to **Engineer Data**?
#
# Let's start with a basic scenario:<br>
# You are HR. You have *no* current database.
# How would you set it up?
#
# Data needs considerations:
# - What you want to store
# - What "views" you anticipate wanting in the future
#
# Structure considerations:
# - Speed of retrieval
# - How much data you are accessing
# - How much you are storing

# %% [markdown]
# ![etl](img/etl.png)
#
# [img source: Jeff Hammerbacher’s slide from UC Berkeley CS 194 course ](https://bcourses.berkeley.edu/courses/1377158/pages/cs-194-16-introduction-to-data-science-fall-2015)

# %% [markdown]
# ### What is a Relational Database?
#
# ![rdb](img/relational-dbms-model.png)
# [reference for image ](https://www.studytonight.com/dbms/database-model.php)

# %% [markdown]
# ### POPULAR RDBMS
#
# - SQLite
# - MySQL
# - PostgreSql
# - Oracle DB
# - SQL Server

# %% [markdown]
# ***
# ### SQL
#
# [History of SQL](https://www.businessnewsdaily.com/5804-what-is-sql.html)
#
# > Future users of large data banks must be protected from having to know how the data is organized in the machine (the internal representation). A prompting service which supplies such information is not a satisfactory solution. Activities of users at terminals and most application programs should remain unaffected when the internal representation of data is changed and even when some aspects of the external representation are changed. Changes in data representation will often be needed as a result of changes in query, update, and report traffic and natural growth in the types of stored information.
# .
# .
# .<br>
# <br>
# In Section 1 a relational model of data is proposed as a basis for protecting users of formatted data systems from the potentially disruptive changes in data representation caused by growth in the data bank and changes in traffic.
#
# [The original SQL paper from the 1970s.](https://www.seas.upenn.edu/~zives/03f/cis550/codd.pdf)

# %% [markdown]
# ***
# ## Goal 2: Database terminology
#
# ### Relational Database Schema
#
# ![schema](img/MySQL_Schema_Music_Example.png)
#
# [source of image](https://database.guide/what-is-a-database-schema/)

# %% [markdown]
# ### Table columns view
# <img src="img/columns.png" width=650>

# %% [markdown]
# ### Terminology
#
# - Database
# - Schema
# - Queries
# - Tables
# - Views
# - Primary Keys
# - Foreign Keys
# - Indexes
# - Functions & User Defined Functions (UDFs)

# %% [markdown]
# ***
# ### SQLite
#
# <img src="img/SQLite-Python.jpg" width=650>
#
# "SQLite is a C library that provides a lightweight disk-based database that doesn’t require a separate server process and allows accessing the database using a nonstandard variant of the SQL query language. Some applications can use SQLite for internal data storage. It’s also possible to prototype an application using SQLite and then port the code to a larger database such as PostgreSQL or Oracle." - [sqlite documentation](https://docs.python.org/2/library/sqlite3.html)

# %% [markdown]
# ## But what about connecting to database servers?
#
# To connect to other database types there are many different libraries:
# - Oracle: [cx_Oracle](https://oracle.github.io/python-cx_Oracle/)
# - MySQL: [MySQL-python](https://github.com/farcepest/MySQLdb1)
# - PostgreSQL: [Psycopg2](http://initd.org/psycopg/docs/)
# - Microsoft SQL Server: [pymssql](http://www.pymssql.org/en/stable/)
#
# These all implement [PEP 249: DB API v2](https://www.python.org/dev/peps/pep-0249/)

# %% [markdown]
# ***
# ## Goal 3: Get going with sqlite!

# %%
import sqlite3

# %% [markdown]
# #### Load a DB object with `connect` and `cursor`

# %%
con = sqlite3.connect('data/flights.db')
cursor = con.cursor()

# %% [markdown]
# #### Get information about one table
#
# **A note about** `execute`<br>
# Each time you use it, you reset the value of cursor

# %%
cursor.execute("SELECT * FROM airports as a").fetchone()
# Out:
# (0,
#  '1',
#  'Goroka',
#  'Goroka',
#  'Papua New Guinea',
#  'GKA',
#  'AYGA',
#  '-6.081689',
#  '145.391881',
#  '5282',
#  '10',
#  'U',
#  'Pacific/Port_Moresby')

# %%
cursor.fetchone()
# Out:
# (1,
#  '2',
#  'Madang',
#  'Madang',
#  'Papua New Guinea',
#  'MAG',
#  'AYMD',
#  '-5.207083',
#  '145.7887',
#  '20',
#  '10',
#  'U',
#  'Pacific/Port_Moresby')

# %%
cursor.fetchmany(4)
# Out:
# [(2,
#   '3',
#   'Mount Hagen',
#   'Mount Hagen',
#   'Papua New Guinea',
#   'HGU',
#   'AYMH',
#   '-5.826789',
#   '144.295861',
#   '5388',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (3,
#   '4',
#   'Nadzab',
#   'Nadzab',
#   'Papua New Guinea',
#   'LAE',
#   'AYNZ',
#   '-6.569828',
#   '146.726242',
#   '239',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (4,
#   '5',
#   'Port Moresby Jacksons Intl',
#   'Port Moresby',
#   'Papua New Guinea',
#   'POM',
#   'AYPY',
#   '-9.443383',
#   '147.22005',
#   '146',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (5,
#   '6',
#   'Wewak Intl',
#   'Wewak',
#   'Papua New Guinea',
#   'WWK',
#   'AYWK',
#   '-3.583828',
#   '143.669186',
#   '19',
#   '10',
#   'U',
#   'Pacific/Port_Moresby')]

# %% [markdown]
# #### Use description

# %%
cursor.description
# Out:
# (('index', None, None, None, None, None, None),
#  ('id', None, None, None, None, None, None),
#  ('name', None, None, None, None, None, None),
#  ('city', None, None, None, None, None, None),
#  ('country', None, None, None, None, None, None),
#  ('code', None, None, None, None, None, None),
#  ('icao', None, None, None, None, None, None),
#  ('latitude', None, None, None, None, None, None),
#  ('longitude', None, None, None, None, None, None),
#  ('altitude', None, None, None, None, None, None),
#  ('offset', None, None, None, None, None, None),
#  ('dst', None, None, None, None, None, None),
#  ('timezone', None, None, None, None, None, None))

# %% [markdown]
# ***
# ## Goal 3: Use basic SQL commands
# - Construct SQL queries
# - Use JOIN to merge tables along logical columns
# - Grouping Data with SQL

# %% [markdown]
# ![](img/flight_schema.png)

# %%
import sqlite3
con = sqlite3.connect('data/flights.db')
cursor = con.cursor()

# %% [markdown]
# ## SELECT and FROM

# %% [markdown]
# SELECT and FROM
# The SELECT statement is followed by the names of the  fields from the table specified by the FROM statement.
#
# Let's select all the columns from the airlines table

# %%
cursor.execute("""
SELECT *
FROM airlines
""")
cursor.fetchmany(5)
# Out:
# [(0, '1', 'Private flight', '\\N', '-', None, None, None, 'Y'),
#  (1, '2', '135 Airways', '\\N', None, 'GNL', 'GENERAL', 'United States', 'N'),
#  (2, '3', '1Time Airline', '\\N', '1T', 'RNX', 'NEXTIME', 'South Africa', 'Y'),
#  (3,
#   '4',
#   '2 Sqn No 1 Elementary Flying Training School',
#   '\\N',
#   None,
#   'WYT',
#   None,
#   'United Kingdom',
#   'N'),
#  (4, '5', '213 Flight Unit', '\\N', None, 'TFU', None, 'Russia', 'N')]

# %% [markdown]
# ## Your turn
#
# Use SELECT and FROM to fetch only the name and city from the airports table.
# **Note: separate the column names with a comma**

# %%
cursor.execute("""

""")
cursor.fetchmany(5)
# Out:
# []

# %% [markdown]
# ## WHERE

# %% [markdown]
# The WHERE clause comes after SELECT, and is used to filter our queries based on some specified criteria.
#
# Let's select the name and country of all airports in the United Kingdom.

# %%
cursor.execute("""
SELECT  name, country
FROM airports
WHERE country = 'United Kingdom'
""")
cursor.fetchmany()
# Out:
# [('Belfast Intl', 'United Kingdom')]

# %% [markdown]
# ## More WHERE:<br>
# Along with `=`, can also use `between`, `in`, wildcards `%`, `AND`, `OR`, `NOT`
#
# ### Your turn
# SELECT the name, country, for all **active** airlines in the United States

# %%
cursor.execute("""

""")
cursor.fetchmany(10)
# Out:
# []

# %% [markdown]
# ## LIKE and %

# %% [markdown]
# Let's use **LIKE** and the % operator to
# SELECT name and country for **active** airlines in the United States which begin with A

# %%
cursor.execute("""
SELECT name, country FROM airlines
WHERE active = 'Y'
AND country = 'United States'
AND name LIKE 'A%'
""")
cursor.fetchmany(10)
# Out:
# [('Aloha Airlines', 'United States'),
#  ('American Airlines', 'United States'),
#  ('Allegiant Air', 'United States'),
#  ('Alaska Central Express', 'United States'),
#  ('Air Cargo Carriers', 'United States'),
#  ('Airlift International', 'United States'),
#  ('America West Airlines', 'United States'),
#  ('Air Wisconsin', 'United States'),
#  ('Allegheny Commuter Airlines', 'United States'),
#  ('Air Sunshine', 'United States')]

# %% [markdown]
# ## ORDER BY
# The ORDER BY clause sorts the data by a specified field.  We can specify ascending and descending by passing ASC and DESC.
#
# Let's order all the airport codes in reverse alphabetical order.

# %%
cursor.execute("""
SELECT code, name FROM airports
ORDER BY code DESC
""")
cursor.fetchmany(10)
# Out:
# [('ИКУ', 'Issyk-Kul International Airport'),
#  ('ZZU', 'Mzuzu'),
#  ('ZYR', 'Brussels Gare du Midi'),
#  ('ZYP', 'Penn Station'),
#  ('ZYL', 'Osmany Intl'),
#  ('ZYA', 'Amsterdam Centraal'),
#  ('ZYA', 'Amsterdam Centraal'),
#  ('ZXE', 'Edinburgh Waverly Station'),
#  ('ZXB', 'Jan Mayensfield'),
#  ('ZWU', 'Washington Union Station')]

# %% [markdown]
# ## Your turn
#
# Fetch source and destination from routes and ORDER BY airline in ascending order

# %%
cursor.execute("""

""")
cursor.fetchmany(10)
# Out:
# []

# %% [markdown]
# ## LIMIT
# Instead of returning all of the results of a query, we can LIMIT the number by a certain amount.  We put the LIMIT clause at the end.
#
# Update your previous query to only return 1 result.

# %% [markdown]
# ## DISTINCT
#
# If you want to look at unique values of a certain field, use DISTINCT in the select clause.
#
# Select the unique countries from our airports table ordered alphabetically.  Limit the result to 10

# %%
cursor.execute("""
SELECT DISTINCT(country) FROM airports
ORDER BY country ASC
LIMIT 10
""")
cursor.fetchall()
# Out:
# [('Afghanistan',),
#  ('Albania',),
#  ('Algeria',),
#  ('American Samoa',),
#  ('Angola',),
#  ('Anguilla',),
#  ('Antarctica',),
#  ('Antigua and Barbuda',),
#  ('Argentina',),
#  ('Armenia',)]

# %% [markdown]
# ## Your turn
# SELECT DISTINCT airlines from our airlines table, limit results to 5.

# %%
cursor.execute("""
SELECT DISTINCT(source) 
FROM routes
LIMIT 10

""")
cursor.fetchall()
# Out:
# [('AER',),
#  ('ASF',),
#  ('CEK',),
#  ('DME',),
#  ('EGO',),
#  ('GYD',),
#  ('KGD',),
#  ('KZN',),
#  ('LED',),
#  ('MRV',)]

# %% [markdown]
# ## Aliases
#
# Aliases can be used for both columns and tables.  Once defined, the aliases can be used to reference the value in other parts of the query.

# %%
cursor.execute("""
SELECT name as na, country as c 
FROM airlines a
WHERE active = 'Y'
AND c = 'United States'
AND na LIKE 'A%'
""")
cursor.fetchmany(10)
# Out:
# [('Aloha Airlines', 'United States'),
#  ('American Airlines', 'United States'),
#  ('Allegiant Air', 'United States'),
#  ('Alaska Central Express', 'United States'),
#  ('Air Cargo Carriers', 'United States'),
#  ('Airlift International', 'United States'),
#  ('America West Airlines', 'United States'),
#  ('Air Wisconsin', 'United States'),
#  ('Allegheny Commuter Airlines', 'United States'),
#  ('Air Sunshine', 'United States')]

# %% [markdown]
# Aliasing the table names becomes very useful when joins are introduced, so let's introduce them

# %% [markdown]
# ### SQL Joins

# %% [markdown]
# SQL joins can be used to both **add** data to a table and **remove** data from a table.

# %% [markdown]
# <img src="img/venn.png" width=550>

# %% [markdown]
# We have to rely on the schema to specify what column the tables join on.

# %% [markdown]
# **Task** Write a query that will join the latitude and longitude data from the airports table to the information on the routes table

# %%
cursor.execute("""
SELECT DISTINCT source, latitude, longitude
FROM airports a
JOIN routes r
ON a.id = r.source_id
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('HGU', '-6.081689', '145.391881')
# ('LAE', '-6.081689', '145.391881')
# ('MAG', '-6.081689', '145.391881')
# ('POM', '-6.081689', '145.391881')
# ('GKA', '-5.207083', '145.7887')
# ('HGU', '-5.207083', '145.7887')
# ('LAE', '-5.207083', '145.7887')
# ('MAS', '-5.207083', '145.7887')
# ('POM', '-5.207083', '145.7887')
# ('VAI', '-5.207083', '145.7887')
# ('WWK', '-5.207083', '145.7887')
# ('GKA', '-5.826789', '144.295861')
# ('LAE', '-5.826789', '144.295861')
# ('MAG', '-5.826789', '144.295861')
# ('MXH', '-5.826789', '144.295861')
# ('POM', '-5.826789', '144.295861')
# ('TBG', '-5.826789', '144.295861')
# ('TIZ', '-5.826789', '144.295861')
# ('UNG', '-5.826789', '144.295861')
# ('WWK', '-5.826789', '144.295861')
# ('DAU', '-6.569828', '146.726242')
# ('GKA', '-6.569828', '146.726242')
# ('HGU', '-6.569828', '146.726242')
# ('HKN', '-6.569828', '146.726242')
# ('MAG', '-6.569828', '146.726242')
# ('MAS', '-6.569828', '146.726242')
# ('PNP', '-6.569828', '146.726242')
# ('POM', '-6.569828', '146.726242')
# ('RAB', '-6.569828', '146.726242')
# ('BNE', '-9.443383', '147.22005')
# ('BUA', '-9.443383', '147.22005')
# ('BUL', '-9.443383', '147.22005')
# ('CEB', '-9.443383', '147.22005')
# ('CMU', '-9.443383', '147.22005')
# ('CNS', '-9.443383', '147.22005')
# ('DAU', '-9.443383', '147.22005')
# ('DPS', '-9.443383', '147.22005')
# ('GKA', '-9.443383', '147.22005')
# ('GUR', '-9.443383', '147.22005')
# ('HGU', '-9.443383', '147.22005')
# ('HIR', '-9.443383', '147.22005')
# ('HKG', '-9.443383', '147.22005')
# ('HKN', '-9.443383', '147.22005')
# ('KVG', '-9.443383', '147.22005')
# ('LAE', '-9.443383', '147.22005')
# ('LNV', '-9.443383', '147.22005')
# ('MAG', '-9.443383', '147.22005')
# ('MAS', '-9.443383', '147.22005')
# ('MDU', '-9.443383', '147.22005')
# ('MNL', '-9.443383', '147.22005')
# ('MXH', '-9.443383', '147.22005')
# ('NAN', '-9.443383', '147.22005')
# ('NRT', '-9.443383', '147.22005')
# ('PNP', '-9.443383', '147.22005')
# ('RAB', '-9.443383', '147.22005')
# ('SIN', '-9.443383', '147.22005')
# ('SYD', '-9.443383', '147.22005')
# ('TBG', '-9.443383', '147.22005')
# ('TIZ', '-9.443383', '147.22005')
# ('UNG', '-9.443383', '147.22005')
# ('VAI', '-9.443383', '147.22005')
# ('WBM', '-9.443383', '147.22005')
# ('WWK', '-9.443383', '147.22005')
# ('YUL', '43.627499', '-79.396167')
# ('YEV', '69.433334', '-133.026389')
# ('AGP', '45.470556', '-73.740833')
# ('ALG', '45.470556', '-73.740833')
# ('AMM', '45.470556', '-73.740833')
# ('AMS', '45.470556', '-73.740833')
# ('ATH', '45.470556', '-73.740833')
# ('ATL', '45.470556', '-73.740833')
# ('AZS', '45.470556', '-73.740833')
# ('BCN', '45.470556', '-73.740833')
# ('BDL', '45.470556', '-73.740833')
# ('BOD', '45.470556', '-73.740833')
# ('BOS', '45.470556', '-73.740833')
# ('BRU', '45.470556', '-73.740833')
# ('CCC', '45.470556', '-73.740833')
# ('CDG', '45.470556', '-73.740833')
# ('CLT', '45.470556', '-73.740833')
# ('CMN', '45.470556', '-73.740833')
# ('CMW', '45.470556', '-73.740833')
# ('CUN', '45.470556', '-73.740833')
# ('CZM', '45.470556', '-73.740833')
# ('DCA', '45.470556', '-73.740833')
# ('DEN', '45.470556', '-73.740833')
# ('DFW', '45.470556', '-73.740833')
# ('DOH', '45.470556', '-73.740833')
# ('DTW', '45.470556', '-73.740833')
# ('EWR', '45.470556', '-73.740833')
# ('FCO', '45.470556', '-73.740833')
# ('FDF', '45.470556', '-73.740833')
# ('FLL', '45.470556', '-73.740833')
# ('FRA', '45.470556', '-73.740833')
# ('FSP', '45.470556', '-73.740833')
# ('GVA', '45.470556', '-73.740833')
# ('HOG', '45.470556', '-73.740833')
# ('IAD', '45.470556', '-73.740833')
# ('IAH', '45.470556', '-73.740833')
# ('JFK', '45.470556', '-73.740833')
# ('LAS', '45.470556', '-73.740833')
# ('LAX', '45.470556', '-73.740833')
# ('LGA', '45.470556', '-73.740833')
# ('LGW', '45.470556', '-73.740833')
# ('LHR', '45.470556', '-73.740833')
# ('LIS', '45.470556', '-73.740833')
# ('LYS', '45.470556', '-73.740833')
# ('MBJ', '45.470556', '-73.740833')
# ('MCO', '45.470556', '-73.740833')
# ('MEX', '45.470556', '-73.740833')
# ('MIA', '45.470556', '-73.740833')
# ('MRS', '45.470556', '-73.740833')
# ('MSP', '45.470556', '-73.740833')
# ('MUC', '45.470556', '-73.740833')
# ('NCE', '45.470556', '-73.740833')
# ('ORD', '45.470556', '-73.740833')
# ('ORY', '45.470556', '-73.740833')
# ('PAP', '45.470556', '-73.740833')
# ('PHL', '45.470556', '-73.740833')
# ('PLS', '45.470556', '-73.740833')
# ('PTP', '45.470556', '-73.740833')
# ('PUJ', '45.470556', '-73.740833')
# ('PVR', '45.470556', '-73.740833')
# ('SCU', '45.470556', '-73.740833')
# ('SFO', '45.470556', '-73.740833')
# ('SNU', '45.470556', '-73.740833')
# ('TLS', '45.470556', '-73.740833')
# ('TLV', '45.470556', '-73.740833')
# ('VCE', '45.470556', '-73.740833')
# ('VRA', '45.470556', '-73.740833')
# ('YBC', '45.470556', '-73.740833')
# ('YBG', '45.470556', '-73.740833')
# ('YEG', '45.470556', '-73.740833')
# ('YFC', '45.470556', '-73.740833')
# ('YGL', '45.470556', '-73.740833')
# ('YGW', '45.470556', '-73.740833')
# ('YYZ', '49.910036', '-97.239886')
# ('YBC', '52.921944', '-66.864444')
# ('YCL', '52.921944', '-66.864444')
# ('YKL', '52.921944', '-66.864444')
# ('YQB', '52.921944', '-66.864444')
# ('YUL', '52.921944', '-66.864444')
# ('YYR', '52.921944', '-66.864444')
# ('YYY', '52.921944', '-66.864444')
# ('YZV', '52.921944', '-66.864444')
# ('ZUM', '52.921944', '-66.864444')
# ('YQZ', '52.183056', '-122.054167')
# ('YVR', '52.183056', '-122.054167')
# ('YLW', '49.612222', '-115.781944')
# ('YVR', '49.612222', '-115.781944')
# ('YYC', '49.612222', '-115.781944')
# ('DEN', '52.170834', '-106.699722')
# ('LAS', '52.170834', '-106.699722')
# ('MSP', '52.170834', '-106.699722')
# ('ORD', '52.170834', '-106.699722')
# ('YEG', '52.170834', '-106.699722')
# ('YVR', '52.170834', '-106.699722')
# ('YWG', '52.170834', '-106.699722')
# ('YYC', '52.170834', '-106.699722')
# ('YYZ', '52.170834', '-106.699722')
# ('YYC', '50.01889', '-110.720833')
# ('YEG', '56.238056', '-120.740278')
# ('YVR', '56.238056', '-120.740278')
# ('YXS', '56.238056', '-120.740278')
# ('YYC', '56.238056', '-120.740278')
# ('YYE', '56.238056', '-120.740278')
# ('KIF', '50.113889', '-91.905278')
# ('MSA', '50.113889', '-91.905278')
# ('SUR', '50.113889', '-91.905278')
# ('WNN', '50.113889', '-91.905278')
# ('XBE', '50.113889', '-91.905278')
# ('XKS', '50.113889', '-91.905278')
# ('YAC', '50.113889', '-91.905278')
# ('YER', '50.113889', '-91.905278')
# ('YHD', '50.113889', '-91.905278')
# ('YPM', '50.113889', '-91.905278')
# ('YQT', '50.113889', '-91.905278')
# ('YRL', '50.113889', '-91.905278')
# ('YTL', '50.113889', '-91.905278')
# ('ZPB', '50.113889', '-91.905278')
# ('YFB', '66.145', '-65.713611')
# ('YVM', '66.145', '-65.713611')
# ('YKA', '53.889444', '-122.678889')
# ('YLW', '53.889444', '-122.678889')
# ('YVR', '53.889444', '-122.678889')
# ('YXJ', '53.889444', '-122.678889')
# ('YXT', '53.889444', '-122.678889')
# ('YYC', '53.889444', '-122.678889')
# ('YYD', '53.889444', '-122.678889')
# ('YYE', '53.889444', '-122.678889')
# ('YVR', '54.468508', '-128.576219')
# ('YXS', '54.468508', '-128.576219')
# ('YYD', '54.468508', '-128.576219')
# ('ORD', '43.033056', '-81.151111')
# ('YOW', '43.033056', '-81.151111')
# ('YWG', '43.033056', '-81.151111')
# ('YYC', '43.033056', '-81.151111')
# ('YYZ', '43.033056', '-81.151111')
# ('YEG', '49.025278', '-122.360556')
# ('YYC', '49.025278', '-122.360556')
# ('YEG', '60.709553', '-135.067269')
# ('YLW', '60.709553', '-135.067269')
# ('YVR', '60.709553', '-135.067269')
# ('YZF', '60.709553', '-135.067269')
# ('YSB', '46.363611', '-79.422778')
# ('YYZ', '46.363611', '-79.422778')
# ('AMS', '51.113888', '-114.020278')
# ('CUN', '51.113888', '-114.020278')
# ('DEN', '51.113888', '-114.020278')
# ('AZR', '31.917223', '5.412778')
# ('DJG', '31.917223', '5.412778')
# ('ELG', '31.917223', '5.412778')
# ('IAM', '31.917223', '5.412778')
# ('ORN', '31.917223', '5.412778')
# ('HME', '28.05155', '9.642911')
# ('OGX', '28.05155', '9.642911')
# ('ABJ', '6.357228', '2.384353')
# ('ABV', '6.357228', '2.384353')
# ('ACC', '6.357228', '2.384353')
# ('ADD', '6.357228', '2.384353')
# ('BKO', '6.357228', '2.384353')
# ('BRU', '6.357228', '2.384353')
# ('BSG', '6.357228', '2.384353')
# ('BZV', '6.357228', '2.384353')
# ('CDG', '6.357228', '2.384353')
# ('CMN', '6.357228', '2.384353')
# ('DKR', '6.357228', '2.384353')
# ('DLA', '6.357228', '2.384353')
# ('LBV', '6.357228', '2.384353')
# ('LFW', '6.357228', '2.384353')
# ('LOS', '6.357228', '2.384353')
# ('NIM', '6.357228', '2.384353')
# ('OUA', '6.357228', '2.384353')
# ('PNR', '6.357228', '2.384353')
# ('SSG', '6.357228', '2.384353')
# ('ABJ', '12.353194', '-1.512417')
# ('ACC', '12.353194', '-1.512417')
# ('ADD', '12.353194', '-1.512417')
# ('ALG', '12.353194', '-1.512417')
# ('BKO', '12.353194', '-1.512417')
# ('BOY', '12.353194', '-1.512417')
# ('BRU', '12.353194', '-1.512417')
# ('CDG', '12.353194', '-1.512417')
# ('CMN', '12.353194', '-1.512417')
# ('COO', '12.353194', '-1.512417')
# ('DKR', '12.353194', '-1.512417')
# ('LFW', '12.353194', '-1.512417')
# ('NIM', '12.353194', '-1.512417')
# ('TUN', '12.353194', '-1.512417')
# ('ABJ', '11.160056', '-4.330969')
# ('OUA', '11.160056', '-4.330969')
# ('ABJ', '5.605186', '-0.166786')
# ('ABV', '5.605186', '-0.166786')
# ('ADD', '5.605186', '-0.166786')
# ('AMS', '5.605186', '-0.166786')
# ('BEY', '5.605186', '-0.166786')
# ('CAI', '5.605186', '-0.166786')
# ('COO', '5.605186', '-0.166786')
# ('DKR', '5.605186', '-0.166786')
# ('DXB', '5.605186', '-0.166786')
# ('FNA', '5.605186', '-0.166786')
# ('FRA', '5.605186', '-0.166786')
# ('IST', '5.605186', '-0.166786')
# ('JFK', '5.605186', '-0.166786')
# ('JNB', '5.605186', '-0.166786')
# ('KMS', '5.605186', '-0.166786')
# ('LFW', '5.605186', '-0.166786')
# ('LHR', '5.605186', '-0.166786')
# ('LIS', '5.605186', '-0.166786')
# ('LOS', '5.605186', '-0.166786')
# ('MAD', '5.605186', '-0.166786')
# ('MLW', '5.605186', '-0.166786')
# ('NBO', '5.605186', '-0.166786')
# ('NYI', '5.605186', '-0.166786')
# ('OUA', '5.605186', '-0.166786')
# ('ROB', '5.605186', '-0.166786')
# ('TKD', '5.605186', '-0.166786')
# ('TML', '5.605186', '-0.166786')
# ('WDH', '5.605186', '-0.166786')
# ('ACC', '9.557192', '-0.863214')
# ('ACC', '7.361828', '-2.328756')
# ('ACC', '4.896056', '-1.774756')
# ('ACC', '5.261386', '-3.926294')
# ('ALG', '5.261386', '-3.926294')
# ('BKO', '5.261386', '-3.926294')
# ('BOY', '5.261386', '-3.926294')
# ('BRU', '5.261386', '-3.926294')
# ('CDG', '5.261386', '-3.926294')
# ('CKY', '5.261386', '-3.926294')
# ('CMN', '5.261386', '-3.926294')
# ('COO', '5.261386', '-3.926294')
# ('DKR', '5.261386', '-3.926294')
# ('DLA', '5.261386', '-3.926294')
# ('FNA', '5.261386', '-3.926294')
# ('LBV', '5.261386', '-3.926294')
# ('LFW', '5.261386', '-3.926294')
# ('LOS', '5.261386', '-3.926294')
# ('NBO', '5.261386', '-3.926294')
# ('ORY', '5.261386', '-3.926294')
# ('OUA', '5.261386', '-3.926294')
# ('ROB', '5.261386', '-3.926294')
# ('TUN', '5.261386', '-3.926294')
# ('ABB', '9.006792', '7.263172')
# ('ACC', '9.006792', '7.263172')
# ('ADD', '9.006792', '7.263172')
# ('BNI', '9.006792', '7.263172')
# ('CAI', '9.006792', '7.263172')
# ('CBQ', '9.006792', '7.263172')
# ('CDG', '9.006792', '7.263172')
# ('COO', '9.006792', '7.263172')
# ('ENU', '9.006792', '7.263172')
# ('FRA', '9.006792', '7.263172')
# ('GMO', '9.006792', '7.263172')
# ('IBA', '9.006792', '7.263172')
# ('ILR', '9.006792', '7.263172')
# ('KAN', '9.006792', '7.263172')
# ('LFW', '9.006792', '7.263172')
# ('LHR', '9.006792', '7.263172')
# ('LOS', '9.006792', '7.263172')
# ('NDJ', '9.006792', '7.263172')
# ('NIM', '9.006792', '7.263172')
# ('PHC', '9.006792', '7.263172')
# ('QOW', '9.006792', '7.263172')
# ('QRW', '9.006792', '7.263172')
# ('SKO', '9.006792', '7.263172')
# ('SSG', '9.006792', '7.263172')
# ('YOL', '9.006792', '7.263172')
# ('ABV', '6.316981', '5.599503')
# ('LOS', '6.316981', '5.599503')
# ('ABV', '4.976019', '8.347197')
# ('LOS', '4.976019', '8.347197')
# ('ABV', '6.474272', '7.561961')
# ('ADD', '6.474272', '7.561961')
# ('LOS', '6.474272', '7.561961')
# ('ABV', '7.362458', '3.978333')
# ('ABV', '8.440211', '4.493919')
# ('LOS', '9.639828', '8.86905')
# ('LOS', '10.696025', '7.320114')
# ('ABV', '12.047589', '8.524622')
# ('BEY', '12.047589', '8.524622')
# ('CAI', '12.047589', '8.524622')
# ('IST', '12.047589', '8.524622')
# ('JED', '12.047589', '8.524622')
# ('LOS', '12.047589', '8.524622')
# ('NDJ', '12.047589', '8.524622')
# ('ABB', '6.577369', '3.321156')
# ('ABJ', '6.577369', '3.321156')
# ('ABV', '6.577369', '3.321156')
# ('ACC', '6.577369', '3.321156')
# ('ADD', '6.577369', '3.321156')
# ('AMM', '6.577369', '3.321156')
# ('AMS', '6.577369', '3.321156')
# ('ATL', '6.577369', '3.321156')
# ('AUH', '6.577369', '3.321156')
# ('BEY', '6.577369', '3.321156')
# ('BKO', '6.577369', '3.321156')
# ('BNI', '6.577369', '3.321156')
# ('CAI', '6.577369', '3.321156')
# ('CBQ', '6.577369', '3.321156')
# ('CDG', '6.577369', '3.321156')
# ('COO', '6.577369', '3.321156')
# ('DKR', '6.577369', '3.321156')
# ('DLA', '6.577369', '3.321156')
# ('DOH', '6.577369', '3.321156')
# ('DXB', '6.577369', '3.321156')
# ('ENU', '6.577369', '3.321156')
# ('FCO', '6.577369', '3.321156')
# ...
# ('RDV', '61.700566', '-157.165833')
# ('SLQ', '61.7875', '-156.591111')
# ('FAI', '63.8675', '-148.968889')
# ('JNU', '56.973056', '-133.945556')
# ('FAI', '64.9975', '-150.644167')
# ('ANC', '56.577222', '-169.663611')
# ('SNP', '56.577222', '-169.663611')
# ('YHO', '54.910278', '-59.785278')
# ('YMN', '54.910278', '-59.785278')
# ('YYR', '54.910278', '-59.785278')
# ('YQC', '61.588611', '-71.929444')
# ('YZG', '61.588611', '-71.929444')
# ('YPN', '50.281944', '-63.611389')
# ('YZV', '50.281944', '-63.611389')
# ('YEG', '58.491389', '-119.407778')
# ('YOJ', '58.491389', '-119.407778')
# ('YBL', '52.139722', '-128.063611')
# ('YKT', '52.139722', '-128.063611')
# ('YZT', '52.139722', '-128.063611')
# ('BZE', '16.966667', '-88.216667')
# ('PLJ', '16.966667', '-88.216667')
# ('SVK', '16.966667', '-88.216667')
# ('TZA', '16.966667', '-88.216667')
# ('BZE', '16.536944', '-88.361667')
# ('DGA', '16.536944', '-88.361667')
# ('INB', '16.536944', '-88.361667')
# ('PND', '16.536944', '-88.361667')
# ('SVK', '16.536944', '-88.361667')
# ('SPB', '17.747222', '-64.705')
# ('LPB', '-20.466667', '-66.833333')
# ('LPB', '-14.4275', '-67.498056')
# ('TDD', '-14.4275', '-67.498056')
# ('BOG', '6.916667', '-71.9')
# ('TME', '6.916667', '-71.9')
# ('ACR', '-0.733333', '-73.016667')
# ('LET', '-0.733333', '-73.016667')
# ('VVC', '2.179167', '-73.7875')
# ('BOG', '0.978889', '-76.605556')
# ('PLU', '-22.921667', '-42.074167')
# ('SDU', '-22.921667', '-42.074167')
# ('VCP', '-22.921667', '-42.074167')
# ('BSB', '-11.885', '-55.586')
# ('CGB', '-11.885', '-55.586')
# ('SXO', '-11.728889', '-49.068889')
# ('CDJ', '-9.505', '-50.625')
# ('BEL', '-1.681944', '-50.48')
# ('MAO', '-2.627778', '-56.735833')
# ('BSB', '-12.083333', '-45')
# ('SSA', '-12.083333', '-45')
# ('GRP', '-13.526944', '-48.220556')
# ('BSB', '-7.228333', '-48.240833')
# ('MAB', '-7.228333', '-48.240833')
# ('PMW', '-7.228333', '-48.240833')
# ('CGR', '-22.220833', '-54.805833')
# ('GRU', '-22.220833', '-54.805833')
# ('VCP', '-22.220833', '-54.805833')
# ('CGB', '-16.466667', '-54.633333')
# ('CWB', '-25.383333', '-51.45')
# ('CFC', '-27.172778', '-51.500833')
# ('ERM', '-27.172778', '-51.500833')
# ('FLN', '-27.172778', '-51.500833')
# ('VCP', '-17.790278', '-50.918333')
# ('PLU', '-19.563056', '-46.960278')
# ('MAO', '-4.085', '-63.140833')
# ('MAO', '-0.975', '-62.923889')
# ('KMG', '23.375833', '104.243056')
# ('TFF', '-0.148056', '-66.9858')
# ('BEL', '-6.11781', '-50.0035')
# ('CNF', '-6.11781', '-50.0035')
# ('MAB', '-6.11781', '-50.0035')
# ('OIA', '-6.11781', '-50.0035')
# ('STM', '-4.2446', '-56.00384')
# ('AWZ', '27.379444', '52.7375')
# ('IFN', '27.379444', '52.7375')
# ('RAS', '27.379444', '52.7375')
# ('SYZ', '27.379444', '52.7375')
# ('THR', '27.379444', '52.7375')
# ('THR', '30.700556', '51.545')
# ('ULN', '49.973333', '92.079722')
# ('KCT', '5.966667', '80.683333')
# ('DME', '37.981667', '69.799444')
# ('LED', '37.981667', '69.799444')
# ('SVX', '37.981667', '69.799444')
# ('EPR', '-33.797222', '120.208056')
# ('PER', '-33.797222', '120.208056')
# ('AZA', '40.21805555', '-111.72222222')
# ('LAX', '40.21805555', '-111.72222222')
# ('OAK', '40.21805555', '-111.72222222')
# ('ABQ', '35.8798019', '-106.2694153')
# ('HIR', '-9.854722', '161.979167')
# ('IRA', '-9.854722', '161.979167')
# ('GZO', '-6.711944', '156.396111')
# ('HIR', '-6.711944', '156.396111')
# ('HIR', '-10.848056', '162.454167')
# ('IRA', '-10.848056', '162.454167')
# ('ERS', '-17.956461', '19.719439')
# ('MPA', '-17.956461', '19.719439')
# ('IOQ', '65.612222', '-37.618333')
# ('KUS', '65.612222', '-37.618333')
# ('KUZ', '65.612222', '-37.618333')
# ('SGG', '65.612222', '-37.618333')
# ('TQI', '65.612222', '-37.618333')
# ('CVG', '40.79935', '-74.4148747')
# ('LUK', '40.79935', '-74.4148747')
# ('ATL', '30.3417', '-85.7973')
# ('BNA', '30.3417', '-85.7973')
# ('BWI', '30.3417', '-85.7973')
# ('HOU', '30.3417', '-85.7973')
# ('STL', '30.3417', '-85.7973')
# ('GYE', '-0.5425', '-78.3657')
# ('OCC', '-0.5425', '-78.3657')
# ('BLR', '12.3072', '76.6497')
# ('CGB', '47.78', '10.627')
# ('DTM', '41.506111', '32.088611')
# ('DUS', '41.506111', '32.088611')
# ('CTU', '24.938651', '98.483591')
# ('JHG', '24.938651', '98.483591')
# ('KMG', '24.938651', '98.483591')
# ('LJG', '24.938651', '98.483591')
# ('DME', '44.691431', '33.57567')
# ('KBP', '44.691431', '33.57567')
# ('XNN', '32.825', '97.125')
# ('PAC', '9.303333', '-78.236111')
# ('CAN', '33.7772', '119.1478')
# ('CKG', '33.7772', '119.1478')
# ('DLC', '33.7772', '119.1478')
# ('FOC', '33.7772', '119.1478')
# ('HKG', '33.7772', '119.1478')
# ('HRB', '33.7772', '119.1478')
# ('PEK', '33.7772', '119.1478')
# ('SHA', '33.7772', '119.1478')
# ('SZX', '33.7772', '119.1478')
# ('TSN', '33.7772', '119.1478')
# ('WNZ', '33.7772', '119.1478')
# ('XIY', '33.7772', '119.1478')
# ('PAC', '9.559167', '-78.971111')
# ('KHG', '32.10027', '80.052778')
# ('LXA', '32.10027', '80.052778')
# ('PAC', '8.68333', '-77.5333')
# ('TZA', '17.269444', '-88.776111')
# ('CAI', '26.341189', '31.742983')
# ('JED', '26.341189', '31.742983')
# ('KWI', '26.341189', '31.742983')
# ('RUH', '26.341189', '31.742983')
# ('SHJ', '26.341189', '31.742983')
# ('AAX', '-18.672778', '-46.491111')
# ('PLU', '-18.672778', '-46.491111')
# ('CGH', '-22.157778', '-49.068333')
# ('MII', '-22.157778', '-49.068333')
# ('VCP', '-22.157778', '-49.068333')
# ('MAB', '-6.763056', '-51.05')
# ('SXX', '-6.763056', '-51.05')
# ('MAB', '-8.033333', '-49.98')
# ('VCP', '-21.247222', '-56.4525')
# ('STZ', '-11.6325', '-50.689444')
# ('CWB', '-26.788333', '-50.939722')
# ('JCB', '-26.788333', '-50.939722')
# ('TFF', '-6.639444', '-69.879722')
# ('TFF', '-3.465556', '-68.918889')
# ('TFF', '-0.416944', '-65.033889')
# ('ATM', '-1.714167', '-55.836111')
# ('MEU', '-1.714167', '-55.836111')
# ('STM', '-1.714167', '-55.836111')
# ('CPH', '36.2993', '32.3014')
# ('ESB', '36.2993', '32.3014')
# ('HEL', '36.2993', '32.3014')
# ('IST', '36.2993', '32.3014')
# ('OSL', '36.2993', '32.3014')
# ('SAW', '36.2993', '32.3014')
# ('ZSJ', '52.991111', '-92.836389')
# ('MED', '26.636718', '37.908018')
# ('RUH', '26.636718', '37.908018')
# ('BMU', '-8.7573222', '116.276675')
# ('CGK', '-8.7573222', '116.276675')
# ('DPS', '-8.7573222', '116.276675')
# ('JOG', '-8.7573222', '116.276675')
# ('KOE', '-8.7573222', '116.276675')
# ('KUL', '-8.7573222', '116.276675')
# ('PER', '-8.7573222', '116.276675')
# ('SIN', '-8.7573222', '116.276675')
# ('SUB', '-8.7573222', '116.276675')
# ('UPG', '-8.7573222', '116.276675')
# ('CAN', '36.524', '114.43')
# ('CKG', '36.524', '114.43')
# ('CTU', '36.524', '114.43')
# ('DLC', '36.524', '114.43')
# ('PVG', '36.524', '114.43')
# ('SHA', '36.524', '114.43')
# ('ALC', '52.451111', '20.651667')
# ('BCN', '52.451111', '20.651667')
# ('BGY', '52.451111', '20.651667')
# ('BLQ', '52.451111', '20.651667')
# ('BRS', '52.451111', '20.651667')
# ('BVA', '52.451111', '20.651667')
# ('CHQ', '52.451111', '20.651667')
# ('CIA', '52.451111', '20.651667')
# ('CRL', '52.451111', '20.651667')
# ('DUB', '52.451111', '20.651667')
# ('EIN', '52.451111', '20.651667')
# ('EMA', '52.451111', '20.651667')
# ('GDN', '52.451111', '20.651667')
# ('LPL', '52.451111', '20.651667')
# ('MAN', '52.451111', '20.651667')
# ('MRS', '52.451111', '20.651667')
# ('NYO', '52.451111', '20.651667')
# ('PIK', '52.451111', '20.651667')
# ('PMI', '52.451111', '20.651667')
# ('PSA', '52.451111', '20.651667')
# ('RYG', '52.451111', '20.651667')
# ('SKG', '52.451111', '20.651667')
# ('SNN', '52.451111', '20.651667')
# ('STN', '52.451111', '20.651667')
# ('TPS', '52.451111', '20.651667')
# ('WRO', '52.451111', '20.651667')
# ('CAN', '27.253', '105.426')
# ('CKG', '27.253', '105.426')
# ('KMG', '27.253', '105.426')
# ('KWE', '27.253', '105.426')
# ('NAY', '27.253', '105.426')
# ('SHA', '27.253', '105.426')
# ('SZX', '27.253', '105.426')
# ('IKT', '60.723', '114.825')
# ('YKS', '60.723', '114.825')
# ('ESB', '39.983056', '43.866389')
# ('IST', '39.983056', '43.866389')
# ('ADB', '37.45', '38.9')
# ('ESB', '37.45', '38.9')
# ('IST', '37.45', '38.9')
# ('SAW', '37.45', '38.9')
# ('IST', '39.111389', '30.13')
# ('ALH', '-33.687222', '115.400278')
# ('PER', '-33.687222', '115.400278')
# ('KMG', '27.8033', '114.3081')
# ('PEK', '27.8033', '114.3081')
# ('SHA', '27.8033', '114.3081')
# ('SZX', '27.8033', '114.3081')
# ('SGN', '19.90167', '105.46778')
# ('UPG', '-2.583333', '119.033333')
# ('BTC', '7.57212', '80.43412')
# ('CMB', '7.57212', '80.43412')
# ('TRR', '7.57212', '80.43412')
# ('ESB', '38.86111', '40.5925')
# ('IST', '38.86111', '40.5925')
# ('IST', '41.316944', '33.796111')
# ('CTU', '29.3231', '100.0533')
# ('LXA', '34.4909', '102.3719')
# ('XIY', '34.4909', '102.3719')
# ('CIA', '37', '14.6144')
# ('CRL', '37', '14.6144')
# ('DUB', '37', '14.6144')
# ('HHN', '37', '14.6144')
# ('KUN', '37', '14.6144')
# ('LIN', '37', '14.6144')
# ('PSA', '37', '14.6144')
# ('STN', '37', '14.6144')

# %% [markdown]
# ## Your turn
# Perform a similar query, but instead of source, change it to reflect destinations.

# %%
cursor.execute("""

""")
print(*cursor.fetchall(), sep='\n')

# %% [markdown]
# The default is **inner join**, which brings in all of the shared indexes across the tables. We can change the JOIN type to LEFT JOIN, which brings in all of the indices of the routes table, and matches them to the airports table.

# %%
cursor.execute("""
SELECT source, dest, a.name 
FROM routes r
LEFT JOIN airports a
ON r.source_id = a.id
LIMIT 10
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('AER', 'KZN', 'Sochi')
# ('ASF', 'KZN', 'Astrakhan')
# ('ASF', 'MRV', 'Astrakhan')
# ('CEK', 'KZN', 'Balandino')
# ('CEK', 'OVB', 'Balandino')
# ('DME', 'KZN', 'Domododevo')
# ('DME', 'NBC', 'Domododevo')
# ('DME', 'TGK', 'Domododevo')
# ('DME', 'UUA', 'Domododevo')
# ('EGO', 'KGD', 'Belgorod International Airport')

# %% [markdown]
# ## COUNT
# In the SELECT statement, we can use certain agregate operators such as COUNT, SUM, MIN, and MAX.
#
# Let's use count to better understand the different types of joins.
#
# Look at the difference between the counts when we use LEFT join vs INNER join

# %%
cursor.execute("""
SELECT COUNT(source_id)
FROM routes r
LEFT JOIN airports a
ON r.source_id = a.id
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# (67663,)

# %%
67663 - 67424
# Out:
# 239

# %%
cursor.execute("""
SELECT COUNT(source_id)
FROM routes r
JOIN airports a
ON r.source_id = a.id
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# (67424,)

# %%
# Why is there a difference?  Let's look at the distince values of the routes source_id
cursor.execute("""
SELECT DISTINCT(source_id)
FROM routes r
ORDER BY source_id DESC
LIMIT 10 
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('\\N',)
# ('999',)
# ('995',)
# ('994',)
# ('990',)
# ('99',)
# ('988',)
# ('986',)
# ('985',)
# ('984',)

# %% [markdown]
# ### Now count the number of times \\\N occurs.

# %%
cursor.execute("""
SELECT COUNT(source_id)
FROM routes r
WHERE source_id = '\\N'
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# (239,)

# %% [markdown]
# The count of \\\N should equal the difference in the two joins.  That is because a left join on routes brings in all indices from routes, but an inner join only brings in indices that match between the two tables.  The routes indices that equal '\\\N' are not present in the airports table.

# %% [markdown]
# ## Joining multiple tables

# %% [markdown]
# In order to fetch the airport names which American Airlines operates out of, we have to join both the routes table and the airports tables. Aliases become very important!

# %%
# Fill in the aliases in the query below to make the joins work correctly. 

cursor.execute("""
SELECT DISTINCT(p.name), a.name
FROM airlines a
JOIN routes r
ON a.id = r.airline_id
JOIN airports p
ON r.source_id = p.id
WHERE a.name = 'American Airlines'
LIMIT 10
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('Ottawa Macdonald Cartier Intl', 'American Airlines')
# ('Banjul Intl', 'American Airlines')
# ('Gran Canaria', 'American Airlines')
# ('Leopold Sedar Senghor Intl', 'American Airlines')
# ('Quebec Jean Lesage Intl', 'American Airlines')
# ('Entebbe Intl', 'American Airlines')
# ('Sofia', 'American Airlines')
# ('Larnaca', 'American Airlines')
# ('Zagreb', 'American Airlines')
# ('Barcelona', 'American Airlines')

# %%
# Now, create a new query which counts the number of airports United Airlines operates out of
cursor.execute("""
SELECT COUNT(p.name), a.name
FROM airlines a
JOIN routes r
ON a.id = r.airline_id
JOIN airports p
ON r.source_id = p.id
WHERE a.name = 'United Airlines'

""")

print(*cursor.fetchall(), sep='\n')
# Out:
# (2180, 'United Airlines')

# %% [markdown]
# ### Grouping statements
#
# Combines `select` and `group by` when you want aggregates by values

# %% [markdown]
# `select` `min(x)` ... `max()`, `sum()`, etc

# %% [markdown]
# `group by x`

# %% [markdown]
# GROUP BY must always be used with an aggregate

# %%
cursor.execute("""
SELECT
    country
  , COUNT(*) AS airline_count
FROM airlines
WHERE active = 'Y'
GROUP BY 1

LIMIT 10
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# (None, 2)
# (' S.A.', 1)
# ('ALASKA', 1)
# ('AVIANCA', 1)
# ('Afghanistan', 4)
# ('Albania', 2)
# ('Algeria', 2)
# ('American Samoa', 1)
# ('Angola', 2)
# ('Antigua and Barbuda', 1)

# %%
# Let's count which airlines run the most routes

cursor.execute("""
SELECT
    a.name, COUNT(r.airline) as airline_count
FROM routes r
JOIN airlines a
on r.airline_id = a.id
GROUP BY airline
ORDER BY airline_count ASC
LIMIT 1
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('Eurowings', 1)

# %% [markdown]
# **Task**<br>
# - Which countries have the highest amount of active airlines?
# - Which countries have the highest amount of inactive airlines?
# - What about airports by timezones?

# %%
# Which countries have the highest amount of active airlines?
cursor.execute("""
SELECT
    country
  , count(*) AS airline_count
FROM airlines
WHERE active = 'Y'
GROUP BY 1
ORDER BY 2 DESC
LIMIT 10
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('United States', 141)
# ('Russia', 72)
# ('United Kingdom', 40)
# ('Germany', 37)
# ('Canada', 34)
# ('Australia', 26)
# ('China', 25)
# ('Spain', 24)
# ('Brazil', 23)
# ('France', 22)

# %%
cursor.description
# Out:
# (('country', None, None, None, None, None, None),
#  ('airline_count', None, None, None, None, None, None))

# %%
# Which countries have the highest amount of inactive airlnes?
cursor.execute("""
SELECT
    country
  , count(*) AS airline_count
FROM airlines
WHERE active = 'N'
GROUP BY country
ORDER BY count(*) DESC
LIMIT 10

""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('United States', 939)
# ('Mexico', 427)
# ('United Kingdom', 367)
# ('Canada', 284)
# ('Russia', 158)
# ('Spain', 142)
# ('France', 97)
# ('Germany', 94)
# ('South Africa', 81)
# ('Nigeria', 80)

# %%
# What about airports by timezones?
cursor.execute("""
SELECT
    timezone AS tz
  , count(*) AS a_cnt
FROM airports
GROUP BY 1
ORDER BY 2 DESC
LIMIT 10
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('America/New_York', 628)
# ('America/Chicago', 373)
# ('Europe/Berlin', 319)
# ('America/Anchorage', 258)
# ('Europe/Paris', 232)
# ('America/Los_Angeles', 226)
# ('Asia/Chongqing', 222)
# ('Europe/London', 193)
# ('America/Toronto', 159)
# ('Asia/Calcutta', 141)

# %% [markdown]
# ## Having
#
# Having is used with a GROUP BY, and filters the data based on a criteria in a similar way to the WHERE clause.
#
# Let's limit our counts

# %%
cursor.execute("""
SELECT
    a.name, COUNT(airline) as airline_count
FROM routes r
JOIN airlines a
on r.airline_id = a.id
GROUP BY airline
HAVING airline_count > 1000
ORDER BY airline_count DESC

""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('Ryanair', 2484)
# ('American Airlines', 2354)
# ('United Airlines', 2180)
# ('Delta Air Lines', 1981)
# ('US Airways', 1960)
# ('China Southern Airlines', 1454)
# ('China Eastern Airlines', 1263)
# ('Air China', 1260)
# ('Southwest Airlines', 1146)
# ('easyJet', 1130)
# ('Air France', 1071)

# %% [markdown]
# We can use many of the same operators we used with WHERE in the HAVING clause

# %%
cursor.execute("""
SELECT
    a.name, COUNT(airline) as airline_count
FROM routes r
JOIN airlines a
on r.airline_id = a.id
WHERE a.name LIKE 'B%'
ORDER BY airline_count ASC
LIMIT 10
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('British Airways', 1581)

# %%
cursor.execute("""
SELECT
    a.name, COUNT(airline) as airline_count
FROM routes r
JOIN airlines a
on r.airline_id = a.id
GROUP BY airline
HAVING a.name LIKE 'B%'
ORDER BY airline_count ASC
LIMIT 10
""")
print(*cursor.fetchall(), sep='\n')
# Out:
# ('Benin Golf Air', 4)
# ('Berjaya Air', 4)
# ('BVI Airways', 6)
# ('bmibaby', 10)
# ('Belair Airlines', 12)
# ('BusinessAir', 12)
# ('BQB Lineas Aereas', 18)
# ('Big Sky Airlines', 36)
# ('Bearskin Lake Air Service', 39)
# ('Baikotovitchestrian Airlines ', 41)

# %%
# It's always a good idea to close our connections when we're done
# cursor.close()
# con.close()

# %% [markdown]
# ## Goal 4: Transfering from sqlite to pandas

# %%
pd_con = sqlite3.connect("flights.db")
df = pd.read_sql_query("select * from airports limit 5;", pd_con)
df

# %% [markdown]
# **Task**:
# Convert one of the earlier queries in the lesson to a pandas data frame

# %%
# Which countries have the highest amount of active airports?
df = pd.read_sql_query("""
-- your code here;
""", pd_con)
df

# %%
pd_con.close()
